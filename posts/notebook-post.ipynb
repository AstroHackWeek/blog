# %% [markdown]
# # This is a Notebook Post

# %% [markdown]
# Here is some Content
#
# $$\int_0^\infty f(x) {\rm d} x = \pi$$
#
# And some code:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,3,2,4,3,5,4,6]);
